# %% [markdown]
# ## PyTorch/TPU MNIST Demo
#
# This colab example corresponds to the implementation under [test_train_mp_mnist.py](https://github.com/pytorch/xla/blob/master/test/test_train_mp_mnist.py).

# %% [markdown]
# <h3>  &nbsp;&nbsp;Use Colab Cloud TPU&nbsp;&nbsp; <a href="https://cloud.google.com/tpu/"><img valign="middle" src="https://raw.githubusercontent.com/GoogleCloudPlatform/tensorflow-without-a-phd/master/tensorflow-rl-pong/images/tpu-hexagon.png" width="50"></a></h3>
#
# * On the main menu, click Runtime and select **Change runtime type**. Set "TPU" as the hardware accelerator.
# * The cell below makes sure you have access to a TPU on Colab.

# %% [markdown]
# ### Define Parameters and Helpers, and start Training

# %%
# Result Visualization Helper
import math
from matplotlib import pyplot as plt

M, N = 4, 6
RESULT_IMG_PATH = '/tmp/test_result.png'

def plot_results(images, labels, preds):
  images, labels, preds = images[:M*N], labels[:M*N], preds[:M*N]
  inv_norm = transforms.Normalize((-0.1307/0.3081,), (1/0.3081,))

  num_images = images.shape[0]
  fig, axes = plt.subplots(M, N, figsize=(11, 9))
  fig.suptitle('Correct / Predicted Labels (Red text for incorrect ones)')

  for i, ax in enumerate(fig.axes):
    ax.axis('off')
    if i >= num_images:
      continue
    img, label, prediction = images[i], labels[i], preds[i]
    img = inv_norm(img)
    img = img.squeeze() # [1,Y,X] -> [Y,X]
    label, prediction = label.item(), prediction.item()
    if label == prediction:
      ax.set_title(u'\u2713', color='blue', fontsize=22)
    else:
      ax.set_title(
          'X {}/{}'.format(label, prediction), color='red')
    ax.imshow(img)
  plt.savefig(RESULT_IMG_PATH, transparent=True)

# %%
# Define Parameters
FLAGS = {}
FLAGS['datadir'] = "/tmp/mnist"
FLAGS['batch_size'] = 128
FLAGS['num_workers'] = 4
FLAGS['learning_rate'] = 0.01
FLAGS['momentum'] = 0.5
FLAGS['num_epochs'] = 10
FLAGS['num_cores'] = 1
FLAGS['log_steps'] = 20
FLAGS['metrics_debug'] = False

# %%
import numpy as np
import os
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.debug.metrics as met
import torch_xla.distributed.parallel_loader as pl
import torch_xla.distributed.xla_multiprocessing as xmp
import torch_xla.utils.utils as xu
from torchvision import datasets, transforms


SERIAL_EXEC = xmp.MpSerialExecutor()

class MNIST(nn.Module):

  def __init__(self):
    super(MNIST, self).__init__()
    self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
    self.bn1 = nn.BatchNorm2d(10)
    self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
    self.bn2 = nn.BatchNorm2d(20)
    self.fc1 = nn.Linear(320, 50)
    self.fc2 = nn.Linear(50, 10)

  def forward(self, x):
    x = F.relu(F.max_pool2d(self.conv1(x), 2))
    x = self.bn1(x)
    x = F.relu(F.max_pool2d(self.conv2(x), 2))
    x = self.bn2(x)
    x = torch.flatten(x, 1)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return F.log_softmax(x, dim=1)

# Only instantiate model weights once in memory.
WRAPPED_MODEL = xmp.MpModelWrapper(MNIST())

def train_mnist():
  torch.manual_seed(1)

  def get_dataset():
    norm = transforms.Normalize((0.1307,), (0.3081,))
    train_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=True,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))
    test_dataset = datasets.MNIST(
        FLAGS['datadir'],
        train=False,
        download=True,
        transform=transforms.Compose(
            [transforms.ToTensor(), norm]))

    return train_dataset, test_dataset

  # Using the serial executor avoids multiple processes to
  # download the same data.
  train_dataset, test_dataset = SERIAL_EXEC.run(get_dataset)

  train_sampler = torch.utils.data.distributed.DistributedSampler(
    train_dataset,
    num_replicas=xm.xrt_world_size(),
    rank=xm.get_ordinal(),
    shuffle=True)
  train_loader = torch.utils.data.DataLoader(
      train_dataset,
      batch_size=FLAGS['batch_size'],
      sampler=train_sampler,
      num_workers=FLAGS['num_workers'],
      drop_last=True)
  test_loader = torch.utils.data.DataLoader(
      test_dataset,
      batch_size=FLAGS['batch_size'],
      shuffle=False,
      num_workers=FLAGS['num_workers'],
      drop_last=True)

  # Scale learning rate to world size
  lr = FLAGS['learning_rate'] * xm.xrt_world_size()

  # Get loss function, optimizer, and model
  device = xm.xla_device()
  model = WRAPPED_MODEL.to(device)
  optimizer = optim.SGD(model.parameters(), lr=lr, momentum=FLAGS['momentum'])
  loss_fn = nn.NLLLoss()

  def train_loop_fn(loader):
    tracker = xm.RateTracker()
    model.train()
    for x, (data, target) in enumerate(loader):
      optimizer.zero_grad()
      output = model(data)
      loss = loss_fn(output, target)
      loss.backward()
      xm.optimizer_step(optimizer)
      tracker.add(FLAGS['batch_size'])
      if x % FLAGS['log_steps'] == 0:
        print('[xla:{}]({}) Loss={:.5f} Rate={:.2f} GlobalRate={:.2f} Time={}'.format(
            xm.get_ordinal(), x, loss.item(), tracker.rate(),
            tracker.global_rate(), time.asctime()), flush=True)

  def test_loop_fn(loader):
    total_samples = 0
    correct = 0
    model.eval()
    data, pred, target = None, None, None
    for data, target in loader:
      output = model(data)
      pred = output.max(1, keepdim=True)[1]
      correct += pred.eq(target.view_as(pred)).sum().item()
      total_samples += data.size()[0]

    accuracy = 100.0 * correct / total_samples
    print('[xla:{}] Accuracy={:.2f}%'.format(
        xm.get_ordinal(), accuracy), flush=True)
    return accuracy, data, pred, target

  # Train and eval loops
  accuracy = 0.0
  data, pred, target = None, None, None
  for epoch in range(1, FLAGS['num_epochs'] + 1):
    para_loader = pl.ParallelLoader(train_loader, [device])
    train_loop_fn(para_loader.per_device_loader(device))
    xm.master_print("Finished training epoch {}".format(epoch))

    para_loader = pl.ParallelLoader(test_loader, [device])
    accuracy, data, pred, target  = test_loop_fn(para_loader.per_device_loader(device))
    if FLAGS['metrics_debug']:
      xm.master_print(met.metrics_report(), flush=True)

  return accuracy, data, pred, target

# %%
# Start training processes
def _mp_fn(rank, flags):
  global FLAGS
  FLAGS = flags
  torch.set_default_tensor_type('torch.FloatTensor')
  accuracy, data, pred, target = train_mnist()
  if rank == 0:
    # Retrieve tensors that are on TPU core 0 and plot.
    plot_results(data.cpu(), pred.cpu(), target.cpu())

xmp.spawn(_mp_fn, args=(FLAGS,), nprocs=FLAGS['num_cores'],
          start_method='fork')
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py:1236: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:434.)
#   _C._set_default_tensor_type(t)
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 41.4MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 1.19MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 11.0MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.76MB/s]
# WARNING:root:torch_xla.core.xla_model.xrt_world_size() will be removed in release 2.7. is deprecated. Use torch_xla.runtime.world_size instead.
# WARNING:root:torch_xla.core.xla_model.xla_model.get_ordinal() will be removed in release 2.7. is deprecated. Use torch_xla.runtime.global_ordinal instead.
# [xla:0](0) Loss=2.34853 Rate=97.26 GlobalRate=97.26 Time=Tue Jun  3 09:25:10 2025
# [xla:0](20) Loss=1.85052 Rate=650.45 GlobalRate=702.24 Time=Tue Jun  3 09:25:13 2025
# [xla:0](40) Loss=1.30080 Rate=8840.21 GlobalRate=1309.78 Time=Tue Jun  3 09:25:13 2025
# [xla:0](60) Loss=0.96269 Rate=14108.31 GlobalRate=1880.51 Time=Tue Jun  3 09:25:13 2025
# [xla:0](80) Loss=0.76132 Rate=14815.14 GlobalRate=2400.26 Time=Tue Jun  3 09:25:13 2025
# [xla:0](100) Loss=0.54704 Rate=14525.85 GlobalRate=2874.07 Time=Tue Jun  3 09:25:14 2025
# [xla:0](120) Loss=0.44466 Rate=16448.77 GlobalRate=3336.11 Time=Tue Jun  3 09:25:14 2025
# [xla:0](140) Loss=0.33286 Rate=16074.42 GlobalRate=3756.63 Time=Tue Jun  3 09:25:14 2025
# [xla:0](160) Loss=0.39503 Rate=17015.98 GlobalRate=4163.74 Time=Tue Jun  3 09:25:14 2025
# [xla:0](180) Loss=0.32781 Rate=15863.72 GlobalRate=4525.90 Time=Tue Jun  3 09:25:14 2025
# [xla:0](200) Loss=0.24094 Rate=17290.81 GlobalRate=4891.90 Time=Tue Jun  3 09:25:14 2025
# [xla:0](220) Loss=0.28864 Rate=15876.48 GlobalRate=5208.87 Time=Tue Jun  3 09:25:14 2025
# [xla:0](240) Loss=0.17818 Rate=17414.03 GlobalRate=5538.67 Time=Tue Jun  3 09:25:15 2025
# [xla:0](260) Loss=0.22300 Rate=16245.51 GlobalRate=5825.19 Time=Tue Jun  3 09:25:15 2025
# [xla:0](280) Loss=0.22516 Rate=15485.22 GlobalRate=6090.07 Time=Tue Jun  3 09:25:15 2025
# [xla:0](300) Loss=0.16533 Rate=15567.15 GlobalRate=6347.41 Time=Tue Jun  3 09:25:15 2025
# [xla:0](320) Loss=0.11577 Rate=15073.32 GlobalRate=6580.92 Time=Tue Jun  3 09:25:15 2025
# [xla:0](340) Loss=0.21573 Rate=15082.41 GlobalRate=6805.99 Time=Tue Jun  3 09:25:15 2025
# [xla:0](360) Loss=0.10848 Rate=16644.93 GlobalRate=7046.14 Time=Tue Jun  3 09:25:16 2025
# [xla:0](380) Loss=0.14188 Rate=15384.47 GlobalRate=7242.13 Time=Tue Jun  3 09:25:16 2025
# [xla:0](400) Loss=0.13348 Rate=14651.82 GlobalRate=7423.05 Time=Tue Jun  3 09:25:16 2025
# [xla:0](420) Loss=0.12724 Rate=16047.63 GlobalRate=7626.96 Time=Tue Jun  3 09:25:16 2025
# [xla:0](440) Loss=0.16518 Rate=14846.28 GlobalRate=7788.37 Time=Tue Jun  3 09:25:16 2025
# [xla:0](460) Loss=0.14175 Rate=14997.08 GlobalRate=7955.46 Time=Tue Jun  3 09:25:16 2025
# Finished training epoch 1
# [xla:0] Accuracy=97.05%
# [xla:0](0) Loss=0.14400 Rate=265.57 GlobalRate=265.57 Time=Tue Jun  3 09:25:21 2025
# [xla:0](20) Loss=0.08067 Rate=8272.73 GlobalRate=4011.46 Time=Tue Jun  3 09:25:21 2025
# [xla:0](40) Loss=0.06899 Rate=13619.45 GlobalRate=6407.50 Time=Tue Jun  3 09:25:21 2025
# [xla:0](60) Loss=0.11483 Rate=14071.15 GlobalRate=7830.23 Time=Tue Jun  3 09:25:21 2025
# [xla:0](80) Loss=0.08940 Rate=14278.58 GlobalRate=8825.85 Time=Tue Jun  3 09:25:21 2025
# [xla:0](100) Loss=0.09467 Rate=15802.25 GlobalRate=9742.65 Time=Tue Jun  3 09:25:22 2025
# [xla:0](120) Loss=0.11007 Rate=14718.67 GlobalRate=10257.90 Time=Tue Jun  3 09:25:22 2025
# [xla:0](140) Loss=0.05733 Rate=14671.99 GlobalRate=10712.84 Time=Tue Jun  3 09:25:22 2025
# [xla:0](160) Loss=0.16858 Rate=16871.75 GlobalRate=11296.33 Time=Tue Jun  3 09:25:22 2025
# [xla:0](180) Loss=0.11523 Rate=15493.69 GlobalRate=11584.29 Time=Tue Jun  3 09:25:22 2025
# [xla:0](200) Loss=0.09684 Rate=14967.50 GlobalRate=11828.44 Time=Tue Jun  3 09:25:22 2025
# [xla:0](220) Loss=0.12206 Rate=16239.69 GlobalRate=12167.37 Time=Tue Jun  3 09:25:23 2025
# [xla:0](240) Loss=0.06259 Rate=15019.01 GlobalRate=12313.97 Time=Tue Jun  3 09:25:23 2025
# [xla:0](260) Loss=0.07771 Rate=14498.37 GlobalRate=12437.71 Time=Tue Jun  3 09:25:23 2025
# [xla:0](280) Loss=0.10118 Rate=12968.20 GlobalRate=12401.54 Time=Tue Jun  3 09:25:23 2025
# [xla:0](300) Loss=0.06980 Rate=13543.28 GlobalRate=12492.44 Time=Tue Jun  3 09:25:23 2025
# [xla:0](320) Loss=0.04398 Rate=16208.11 GlobalRate=12734.75 Time=Tue Jun  3 09:25:23 2025
# [xla:0](340) Loss=0.12867 Rate=15437.10 GlobalRate=12845.22 Time=Tue Jun  3 09:25:24 2025
# [xla:0](360) Loss=0.05965 Rate=14853.57 GlobalRate=12925.39 Time=Tue Jun  3 09:25:24 2025
# [xla:0](380) Loss=0.07474 Rate=16671.48 GlobalRate=13116.28 Time=Tue Jun  3 09:25:24 2025
# [xla:0](400) Loss=0.06813 Rate=15184.59 GlobalRate=13166.11 Time=Tue Jun  3 09:25:24 2025
# [xla:0](420) Loss=0.07108 Rate=14760.87 GlobalRate=13223.04 Time=Tue Jun  3 09:25:24 2025
# [xla:0](440) Loss=0.07520 Rate=16554.08 GlobalRate=13377.77 Time=Tue Jun  3 09:25:24 2025
# [xla:0](460) Loss=0.09127 Rate=12551.20 GlobalRate=13175.61 Time=Tue Jun  3 09:25:25 2025
# Finished training epoch 2
# [xla:0] Accuracy=97.95%
# [xla:0](0) Loss=0.08925 Rate=265.16 GlobalRate=265.15 Time=Tue Jun  3 09:25:28 2025
# [xla:0](20) Loss=0.05222 Rate=6960.57 GlobalRate=3802.89 Time=Tue Jun  3 09:25:28 2025
# [xla:0](40) Loss=0.03471 Rate=10760.82 GlobalRate=5835.11 Time=Tue Jun  3 09:25:28 2025
# [xla:0](60) Loss=0.09407 Rate=12797.12 GlobalRate=7228.00 Time=Tue Jun  3 09:25:29 2025
# [xla:0](80) Loss=0.04165 Rate=16039.40 GlobalRate=8492.12 Time=Tue Jun  3 09:25:29 2025
# [xla:0](100) Loss=0.06862 Rate=14905.90 GlobalRate=9222.35 Time=Tue Jun  3 09:25:29 2025
# [xla:0](120) Loss=0.08281 Rate=14819.69 GlobalRate=9832.24 Time=Tue Jun  3 09:25:29 2025
# [xla:0](140) Loss=0.03008 Rate=16146.17 GlobalRate=10459.30 Time=Tue Jun  3 09:25:29 2025
# [xla:0](160) Loss=0.13356 Rate=15027.73 GlobalRate=10819.04 Time=Tue Jun  3 09:25:29 2025
# [xla:0](180) Loss=0.08080 Rate=14616.41 GlobalRate=11120.90 Time=Tue Jun  3 09:25:30 2025
# [xla:0](200) Loss=0.07161 Rate=14318.35 GlobalRate=11360.98 Time=Tue Jun  3 09:25:30 2025
# [xla:0](220) Loss=0.09387 Rate=16724.27 GlobalRate=11765.74 Time=Tue Jun  3 09:25:30 2025
# [xla:0](240) Loss=0.03874 Rate=15358.83 GlobalRate=11949.88 Time=Tue Jun  3 09:25:30 2025
# [xla:0](260) Loss=0.04949 Rate=14659.75 GlobalRate=12096.41 Time=Tue Jun  3 09:25:30 2025
# [xla:0](280) Loss=0.06436 Rate=16250.04 GlobalRate=12361.41 Time=Tue Jun  3 09:25:30 2025
# [xla:0](300) Loss=0.05126 Rate=15133.39 GlobalRate=12478.25 Time=Tue Jun  3 09:25:31 2025
# [xla:0](320) Loss=0.02707 Rate=14694.95 GlobalRate=12582.99 Time=Tue Jun  3 09:25:31 2025
# [xla:0](340) Loss=0.10758 Rate=16097.49 GlobalRate=12778.79 Time=Tue Jun  3 09:25:31 2025
# [xla:0](360) Loss=0.04458 Rate=14877.81 GlobalRate=12843.85 Time=Tue Jun  3 09:25:31 2025
# [xla:0](380) Loss=0.05604 Rate=14815.89 GlobalRate=12932.56 Time=Tue Jun  3 09:25:31 2025
# [xla:0](400) Loss=0.04660 Rate=16300.77 GlobalRate=13097.21 Time=Tue Jun  3 09:25:31 2025
# [xla:0](420) Loss=0.05884 Rate=15027.01 GlobalRate=13144.81 Time=Tue Jun  3 09:25:32 2025
# [xla:0](440) Loss=0.04563 Rate=15448.95 GlobalRate=13243.52 Time=Tue Jun  3 09:25:32 2025
# [xla:0](460) Loss=0.07029 Rate=9860.81 GlobalRate=12609.73 Time=Tue Jun  3 09:25:32 2025
# Finished training epoch 3
# [xla:0] Accuracy=98.26%
# [xla:0](0) Loss=0.07079 Rate=270.49 GlobalRate=270.48 Time=Tue Jun  3 09:25:35 2025
# [xla:0](20) Loss=0.04027 Rate=8019.85 GlobalRate=4027.69 Time=Tue Jun  3 09:25:36 2025
# [xla:0](40) Loss=0.02793 Rate=11795.96 GlobalRate=6201.66 Time=Tue Jun  3 09:25:36 2025
# [xla:0](60) Loss=0.08355 Rate=13443.39 GlobalRate=7637.90 Time=Tue Jun  3 09:25:36 2025
# [xla:0](80) Loss=0.02811 Rate=16002.15 GlobalRate=8885.55 Time=Tue Jun  3 09:25:36 2025
# [xla:0](100) Loss=0.05893 Rate=15007.29 GlobalRate=9609.68 Time=Tue Jun  3 09:25:36 2025
# [xla:0](120) Loss=0.06315 Rate=14701.46 GlobalRate=10176.82 Time=Tue Jun  3 09:25:37 2025
# [xla:0](140) Loss=0.02076 Rate=16767.08 GlobalRate=10852.79 Time=Tue Jun  3 09:25:37 2025
# [xla:0](160) Loss=0.11195 Rate=15378.50 GlobalRate=11199.32 Time=Tue Jun  3 09:25:37 2025
# [xla:0](180) Loss=0.06599 Rate=16603.82 GlobalRate=11659.41 Time=Tue Jun  3 09:25:37 2025
# [xla:0](200) Loss=0.06284 Rate=15166.00 GlobalRate=11871.26 Time=Tue Jun  3 09:25:37 2025
# [xla:0](220) Loss=0.08006 Rate=14360.67 GlobalRate=12024.97 Time=Tue Jun  3 09:25:37 2025
# [xla:0](240) Loss=0.02493 Rate=13932.53 GlobalRate=12144.77 Time=Tue Jun  3 09:25:38 2025
# [xla:0](260) Loss=0.03860 Rate=13643.33 GlobalRate=12235.79 Time=Tue Jun  3 09:25:38 2025
# [xla:0](280) Loss=0.04539 Rate=13548.61 GlobalRate=12317.02 Time=Tue Jun  3 09:25:38 2025
# [xla:0](300) Loss=0.04315 Rate=14036.13 GlobalRate=12434.63 Time=Tue Jun  3 09:25:38 2025
# [xla:0](320) Loss=0.02061 Rate=14335.70 GlobalRate=12547.62 Time=Tue Jun  3 09:25:38 2025
# [xla:0](340) Loss=0.09740 Rate=14573.89 GlobalRate=12657.72 Time=Tue Jun  3 09:25:38 2025
# [xla:0](360) Loss=0.03648 Rate=14630.18 GlobalRate=12754.56 Time=Tue Jun  3 09:25:39 2025
# [xla:0](380) Loss=0.04874 Rate=17129.75 GlobalRate=12973.46 Time=Tue Jun  3 09:25:39 2025
# [xla:0](400) Loss=0.03615 Rate=15712.60 GlobalRate=13052.56 Time=Tue Jun  3 09:25:39 2025
# [xla:0](420) Loss=0.04826 Rate=17145.11 GlobalRate=13227.80 Time=Tue Jun  3 09:25:39 2025
# [xla:0](440) Loss=0.03241 Rate=16718.11 GlobalRate=13345.86 Time=Tue Jun  3 09:25:39 2025
# [xla:0](460) Loss=0.05406 Rate=10567.09 GlobalRate=12757.06 Time=Tue Jun  3 09:25:40 2025
# Finished training epoch 4
# [xla:0] Accuracy=98.49%
# [xla:0](0) Loss=0.05866 Rate=267.66 GlobalRate=267.66 Time=Tue Jun  3 09:25:44 2025
# [xla:0](20) Loss=0.03054 Rate=8407.08 GlobalRate=4052.48 Time=Tue Jun  3 09:25:44 2025
# [xla:0](40) Loss=0.02457 Rate=11832.15 GlobalRate=6213.27 Time=Tue Jun  3 09:25:44 2025
# [xla:0](60) Loss=0.07689 Rate=15169.21 GlobalRate=7872.38 Time=Tue Jun  3 09:25:44 2025
# [xla:0](80) Loss=0.02110 Rate=14809.30 GlobalRate=8880.27 Time=Tue Jun  3 09:25:44 2025
# [xla:0](100) Loss=0.05272 Rate=14704.43 GlobalRate=9630.07 Time=Tue Jun  3 09:25:45 2025
# [xla:0](120) Loss=0.04829 Rate=16108.40 GlobalRate=10376.12 Time=Tue Jun  3 09:25:45 2025
# [xla:0](140) Loss=0.01631 Rate=15134.41 GlobalRate=10811.13 Time=Tue Jun  3 09:25:45 2025
# [xla:0](160) Loss=0.09405 Rate=15338.08 GlobalRate=11231.55 Time=Tue Jun  3 09:25:45 2025
# [xla:0](180) Loss=0.05737 Rate=17231.27 GlobalRate=11740.98 Time=Tue Jun  3 09:25:45 2025
# [xla:0](200) Loss=0.05815 Rate=15754.37 GlobalRate=11985.55 Time=Tue Jun  3 09:25:45 2025
# [xla:0](220) Loss=0.07272 Rate=16809.06 GlobalRate=12337.91 Time=Tue Jun  3 09:25:46 2025
# [xla:0](240) Loss=0.01764 Rate=15403.32 GlobalRate=12490.41 Time=Tue Jun  3 09:25:46 2025
# [xla:0](260) Loss=0.03243 Rate=15178.96 GlobalRate=12654.22 Time=Tue Jun  3 09:25:46 2025
# [xla:0](280) Loss=0.03679 Rate=16731.66 GlobalRate=12918.81 Time=Tue Jun  3 09:25:46 2025
# [xla:0](300) Loss=0.03696 Rate=15485.94 GlobalRate=13021.34 Time=Tue Jun  3 09:25:46 2025
# [xla:0](320) Loss=0.01637 Rate=14986.83 GlobalRate=13112.36 Time=Tue Jun  3 09:25:46 2025
# [xla:0](340) Loss=0.09044 Rate=16556.49 GlobalRate=13311.53 Time=Tue Jun  3 09:25:47 2025
# [xla:0](360) Loss=0.03129 Rate=15465.11 GlobalRate=13383.27 Time=Tue Jun  3 09:25:47 2025
# [xla:0](380) Loss=0.04329 Rate=14900.60 GlobalRate=13438.69 Time=Tue Jun  3 09:25:47 2025
# [xla:0](400) Loss=0.03053 Rate=16226.83 GlobalRate=13584.10 Time=Tue Jun  3 09:25:47 2025
# [xla:0](420) Loss=0.04098 Rate=15636.52 GlobalRate=13654.69 Time=Tue Jun  3 09:25:47 2025
# [xla:0](440) Loss=0.02420 Rate=16753.85 GlobalRate=13792.10 Time=Tue Jun  3 09:25:47 2025
# [xla:0](460) Loss=0.04185 Rate=16041.78 GlobalRate=13860.66 Time=Tue Jun  3 09:25:48 2025
# Finished training epoch 5
# [xla:0] Accuracy=98.64%
# [xla:0](0) Loss=0.04838 Rate=242.55 GlobalRate=242.55 Time=Tue Jun  3 09:25:52 2025
# [xla:0](20) Loss=0.02420 Rate=8409.30 GlobalRate=3772.49 Time=Tue Jun  3 09:25:52 2025
# [xla:0](40) Loss=0.02191 Rate=12079.87 GlobalRate=5904.98 Time=Tue Jun  3 09:25:53 2025
# [xla:0](60) Loss=0.06796 Rate=13396.50 GlobalRate=7310.28 Time=Tue Jun  3 09:25:53 2025
# [xla:0](80) Loss=0.01759 Rate=16049.53 GlobalRate=8556.16 Time=Tue Jun  3 09:25:53 2025
# [xla:0](100) Loss=0.04889 Rate=15055.83 GlobalRate=9303.28 Time=Tue Jun  3 09:25:53 2025
# [xla:0](120) Loss=0.03874 Rate=16612.04 GlobalRate=10092.11 Time=Tue Jun  3 09:25:53 2025
# [xla:0](140) Loss=0.01381 Rate=15134.88 GlobalRate=10520.05 Time=Tue Jun  3 09:25:53 2025
# [xla:0](160) Loss=0.07752 Rate=12189.27 GlobalRate=10482.52 Time=Tue Jun  3 09:25:54 2025
# [xla:0](180) Loss=0.05497 Rate=15500.64 GlobalRate=10977.49 Time=Tue Jun  3 09:25:54 2025
# [xla:0](200) Loss=0.05746 Rate=15124.43 GlobalRate=11271.27 Time=Tue Jun  3 09:25:54 2025
# [xla:0](220) Loss=0.06523 Rate=16445.52 GlobalRate=11639.37 Time=Tue Jun  3 09:25:54 2025
# [xla:0](240) Loss=0.01319 Rate=15501.54 GlobalRate=11853.20 Time=Tue Jun  3 09:25:54 2025
# [xla:0](260) Loss=0.02987 Rate=15020.77 GlobalRate=12031.76 Time=Tue Jun  3 09:25:55 2025
# [xla:0](280) Loss=0.02936 Rate=16756.13 GlobalRate=12319.65 Time=Tue Jun  3 09:25:55 2025
# [xla:0](300) Loss=0.03205 Rate=15256.34 GlobalRate=12431.87 Time=Tue Jun  3 09:25:55 2025
# [xla:0](320) Loss=0.01471 Rate=15035.46 GlobalRate=12560.99 Time=Tue Jun  3 09:25:55 2025
# [xla:0](340) Loss=0.08748 Rate=16644.75 GlobalRate=12779.13 Time=Tue Jun  3 09:25:55 2025
# [xla:0](360) Loss=0.02809 Rate=15538.72 GlobalRate=12876.60 Time=Tue Jun  3 09:25:55 2025
# [xla:0](380) Loss=0.03977 Rate=14922.73 GlobalRate=12953.23 Time=Tue Jun  3 09:25:56 2025
# [xla:0](400) Loss=0.02501 Rate=16445.54 GlobalRate=13122.18 Time=Tue Jun  3 09:25:56 2025
# [xla:0](420) Loss=0.03609 Rate=15821.48 GlobalRate=13215.23 Time=Tue Jun  3 09:25:56 2025
# [xla:0](440) Loss=0.01928 Rate=17860.13 GlobalRate=13405.15 Time=Tue Jun  3 09:25:56 2025
# [xla:0](460) Loss=0.03547 Rate=17018.75 GlobalRate=13513.90 Time=Tue Jun  3 09:25:56 2025
# Finished training epoch 6
# [xla:0] Accuracy=98.72%
# [xla:0](0) Loss=0.04200 Rate=243.83 GlobalRate=243.82 Time=Tue Jun  3 09:26:01 2025
# [xla:0](20) Loss=0.01971 Rate=7410.01 GlobalRate=3657.00 Time=Tue Jun  3 09:26:01 2025
# [xla:0](40) Loss=0.02018 Rate=13072.22 GlobalRate=5916.75 Time=Tue Jun  3 09:26:01 2025
# [xla:0](60) Loss=0.06111 Rate=13607.06 GlobalRate=7295.10 Time=Tue Jun  3 09:26:01 2025
# [xla:0](80) Loss=0.01495 Rate=13757.42 GlobalRate=8261.07 Time=Tue Jun  3 09:26:01 2025
# [xla:0](100) Loss=0.04306 Rate=13916.09 GlobalRate=8992.67 Time=Tue Jun  3 09:26:02 2025
# [xla:0](120) Loss=0.03289 Rate=15930.92 GlobalRate=9766.59 Time=Tue Jun  3 09:26:02 2025
# [xla:0](140) Loss=0.01218 Rate=14815.27 GlobalRate=10209.64 Time=Tue Jun  3 09:26:02 2025
# [xla:0](160) Loss=0.06754 Rate=14505.29 GlobalRate=10585.69 Time=Tue Jun  3 09:26:02 2025
# [xla:0](180) Loss=0.05005 Rate=14279.40 GlobalRate=10887.37 Time=Tue Jun  3 09:26:02 2025
# [xla:0](200) Loss=0.05666 Rate=16005.03 GlobalRate=11298.12 Time=Tue Jun  3 09:26:02 2025
# [xla:0](220) Loss=0.05899 Rate=15084.57 GlobalRate=11526.84 Time=Tue Jun  3 09:26:03 2025
# [xla:0](240) Loss=0.01105 Rate=14559.20 GlobalRate=11710.27 Time=Tue Jun  3 09:26:03 2025
# [xla:0](260) Loss=0.02754 Rate=15945.01 GlobalRate=11991.27 Time=Tue Jun  3 09:26:03 2025
# [xla:0](280) Loss=0.02496 Rate=14637.85 GlobalRate=12102.34 Time=Tue Jun  3 09:26:03 2025
# [xla:0](300) Loss=0.02830 Rate=14524.71 GlobalRate=12234.38 Time=Tue Jun  3 09:26:03 2025
# [xla:0](320) Loss=0.01317 Rate=14353.49 GlobalRate=12342.66 Time=Tue Jun  3 09:26:04 2025
# [xla:0](340) Loss=0.08874 Rate=16222.35 GlobalRate=12558.79 Time=Tue Jun  3 09:26:04 2025
# [xla:0](360) Loss=0.02551 Rate=14626.39 GlobalRate=12610.49 Time=Tue Jun  3 09:26:04 2025
# [xla:0](380) Loss=0.03804 Rate=15163.71 GlobalRate=12735.89 Time=Tue Jun  3 09:26:04 2025
# [xla:0](400) Loss=0.02337 Rate=16398.40 GlobalRate=12903.52 Time=Tue Jun  3 09:26:04 2025
# [xla:0](420) Loss=0.03161 Rate=15530.11 GlobalRate=12988.03 Time=Tue Jun  3 09:26:04 2025
# [xla:0](440) Loss=0.01629 Rate=16258.64 GlobalRate=13121.52 Time=Tue Jun  3 09:26:04 2025
# [xla:0](460) Loss=0.03083 Rate=10032.37 GlobalRate=12456.30 Time=Tue Jun  3 09:26:05 2025
# Finished training epoch 7
# [xla:0] Accuracy=98.81%
# [xla:0](0) Loss=0.03578 Rate=209.47 GlobalRate=209.47 Time=Tue Jun  3 09:26:10 2025
# [xla:0](20) Loss=0.01665 Rate=7375.49 GlobalRate=3271.17 Time=Tue Jun  3 09:26:10 2025
# [xla:0](40) Loss=0.01930 Rate=11304.28 GlobalRate=5218.89 Time=Tue Jun  3 09:26:10 2025
# [xla:0](60) Loss=0.05360 Rate=12888.11 GlobalRate=6565.93 Time=Tue Jun  3 09:26:10 2025
# [xla:0](80) Loss=0.01261 Rate=13245.06 GlobalRate=7518.29 Time=Tue Jun  3 09:26:10 2025
# [xla:0](100) Loss=0.03900 Rate=15719.01 GlobalRate=8469.43 Time=Tue Jun  3 09:26:10 2025
# [xla:0](120) Loss=0.02836 Rate=14355.76 GlobalRate=9021.38 Time=Tue Jun  3 09:26:11 2025
# [xla:0](140) Loss=0.01069 Rate=14232.92 GlobalRate=9510.38 Time=Tue Jun  3 09:26:11 2025
# [xla:0](160) Loss=0.05874 Rate=14281.37 GlobalRate=9924.08 Time=Tue Jun  3 09:26:11 2025
# [xla:0](180) Loss=0.04645 Rate=16221.42 GlobalRate=10423.23 Time=Tue Jun  3 09:26:11 2025
# [xla:0](200) Loss=0.05476 Rate=15099.16 GlobalRate=10715.03 Time=Tue Jun  3 09:26:11 2025
# [xla:0](220) Loss=0.05286 Rate=17138.48 GlobalRate=11139.18 Time=Tue Jun  3 09:26:11 2025
# [xla:0](240) Loss=0.00991 Rate=15243.27 GlobalRate=11330.23 Time=Tue Jun  3 09:26:12 2025
# [xla:0](260) Loss=0.02589 Rate=14979.08 GlobalRate=11537.64 Time=Tue Jun  3 09:26:12 2025
# [xla:0](280) Loss=0.02103 Rate=14677.73 GlobalRate=11706.81 Time=Tue Jun  3 09:26:12 2025
# [xla:0](300) Loss=0.02531 Rate=16544.59 GlobalRate=11978.95 Time=Tue Jun  3 09:26:12 2025
# [xla:0](320) Loss=0.01173 Rate=15486.90 GlobalRate=12122.16 Time=Tue Jun  3 09:26:12 2025
# [xla:0](340) Loss=0.08924 Rate=16360.39 GlobalRate=12327.88 Time=Tue Jun  3 09:26:12 2025
# [xla:0](360) Loss=0.02215 Rate=15033.47 GlobalRate=12416.42 Time=Tue Jun  3 09:26:13 2025
# [xla:0](380) Loss=0.03534 Rate=14793.94 GlobalRate=12515.99 Time=Tue Jun  3 09:26:13 2025
# [xla:0](400) Loss=0.02020 Rate=14525.88 GlobalRate=12596.17 Time=Tue Jun  3 09:26:13 2025
# [xla:0](420) Loss=0.02714 Rate=15970.76 GlobalRate=12751.34 Time=Tue Jun  3 09:26:13 2025
# [xla:0](440) Loss=0.01331 Rate=14738.11 GlobalRate=12799.94 Time=Tue Jun  3 09:26:13 2025
# [xla:0](460) Loss=0.02838 Rate=9008.43 GlobalRate=12034.08 Time=Tue Jun  3 09:26:14 2025
# Finished training epoch 8
# [xla:0] Accuracy=98.82%
# [xla:0](0) Loss=0.03091 Rate=218.11 GlobalRate=218.10 Time=Tue Jun  3 09:26:19 2025
# [xla:0](20) Loss=0.01435 Rate=10059.03 GlobalRate=3627.94 Time=Tue Jun  3 09:26:19 2025
# [xla:0](40) Loss=0.01675 Rate=9597.91 GlobalRate=5163.03 Time=Tue Jun  3 09:26:19 2025
# [xla:0](60) Loss=0.04598 Rate=12367.29 GlobalRate=6525.34 Time=Tue Jun  3 09:26:19 2025
# [xla:0](80) Loss=0.01069 Rate=15220.38 GlobalRate=7702.38 Time=Tue Jun  3 09:26:19 2025
# [xla:0](100) Loss=0.03390 Rate=14500.79 GlobalRate=8457.08 Time=Tue Jun  3 09:26:19 2025
# [xla:0](120) Loss=0.02474 Rate=14466.65 GlobalRate=9079.09 Time=Tue Jun  3 09:26:20 2025
# [xla:0](140) Loss=0.00954 Rate=16417.72 GlobalRate=9753.67 Time=Tue Jun  3 09:26:20 2025
# [xla:0](160) Loss=0.05398 Rate=15800.07 GlobalRate=10218.47 Time=Tue Jun  3 09:26:20 2025
# [xla:0](180) Loss=0.04086 Rate=14966.37 GlobalRate=10557.84 Time=Tue Jun  3 09:26:20 2025
# [xla:0](200) Loss=0.05399 Rate=16745.38 GlobalRate=11008.26 Time=Tue Jun  3 09:26:20 2025
# [xla:0](220) Loss=0.04936 Rate=15581.12 GlobalRate=11269.81 Time=Tue Jun  3 09:26:20 2025
# [xla:0](240) Loss=0.00894 Rate=14954.21 GlobalRate=11483.95 Time=Tue Jun  3 09:26:21 2025
# [xla:0](260) Loss=0.02500 Rate=16695.26 GlobalRate=11806.82 Time=Tue Jun  3 09:26:21 2025
# [xla:0](280) Loss=0.01894 Rate=15724.24 GlobalRate=11991.94 Time=Tue Jun  3 09:26:21 2025
# [xla:0](300) Loss=0.02335 Rate=16908.22 GlobalRate=12254.46 Time=Tue Jun  3 09:26:21 2025
# [xla:0](320) Loss=0.01031 Rate=15408.55 GlobalRate=12369.69 Time=Tue Jun  3 09:26:21 2025
# [xla:0](340) Loss=0.08800 Rate=15302.83 GlobalRate=12507.55 Time=Tue Jun  3 09:26:21 2025
# [xla:0](360) Loss=0.02041 Rate=16588.70 GlobalRate=12706.83 Time=Tue Jun  3 09:26:22 2025
# [xla:0](380) Loss=0.03249 Rate=15402.78 GlobalRate=12794.40 Time=Tue Jun  3 09:26:22 2025
# [xla:0](400) Loss=0.01798 Rate=15137.27 GlobalRate=12887.46 Time=Tue Jun  3 09:26:22 2025
# [xla:0](420) Loss=0.02420 Rate=16711.48 GlobalRate=13057.67 Time=Tue Jun  3 09:26:22 2025
# [xla:0](440) Loss=0.01114 Rate=15528.57 GlobalRate=13125.61 Time=Tue Jun  3 09:26:22 2025
# [xla:0](460) Loss=0.02708 Rate=16985.97 GlobalRate=13280.64 Time=Tue Jun  3 09:26:22 2025
# Finished training epoch 9
# [xla:0] Accuracy=98.87%
# [xla:0](0) Loss=0.02788 Rate=269.02 GlobalRate=269.01 Time=Tue Jun  3 09:26:26 2025
# [xla:0](20) Loss=0.01243 Rate=7664.52 GlobalRate=3958.30 Time=Tue Jun  3 09:26:26 2025
# [xla:0](40) Loss=0.01441 Rate=11360.05 GlobalRate=6072.25 Time=Tue Jun  3 09:26:26 2025
# [xla:0](60) Loss=0.03839 Rate=13063.21 GlobalRate=7474.94 Time=Tue Jun  3 09:26:26 2025
# [xla:0](80) Loss=0.00947 Rate=15614.99 GlobalRate=8695.09 Time=Tue Jun  3 09:26:26 2025
# [xla:0](100) Loss=0.03055 Rate=14839.40 GlobalRate=9428.66 Time=Tue Jun  3 09:26:27 2025
# [xla:0](120) Loss=0.02181 Rate=14148.88 GlobalRate=9939.96 Time=Tue Jun  3 09:26:27 2025
# [xla:0](140) Loss=0.00840 Rate=14192.40 GlobalRate=10383.36 Time=Tue Jun  3 09:26:27 2025
# [xla:0](160) Loss=0.04785 Rate=15975.59 GlobalRate=10919.23 Time=Tue Jun  3 09:26:27 2025
# [xla:0](180) Loss=0.03777 Rate=15020.73 GlobalRate=11217.82 Time=Tue Jun  3 09:26:27 2025
# [xla:0](200) Loss=0.05208 Rate=14564.31 GlobalRate=11461.11 Time=Tue Jun  3 09:26:27 2025
# [xla:0](220) Loss=0.04504 Rate=16381.79 GlobalRate=11834.41 Time=Tue Jun  3 09:26:28 2025
# [xla:0](240) Loss=0.00831 Rate=15276.71 GlobalRate=12020.03 Time=Tue Jun  3 09:26:28 2025
# [xla:0](260) Loss=0.02445 Rate=15144.30 GlobalRate=12208.67 Time=Tue Jun  3 09:26:28 2025
# [xla:0](280) Loss=0.01672 Rate=16677.89 GlobalRate=12484.36 Time=Tue Jun  3 09:26:28 2025
# [xla:0](300) Loss=0.02180 Rate=15858.93 GlobalRate=12639.49 Time=Tue Jun  3 09:26:28 2025
# [xla:0](320) Loss=0.00878 Rate=14650.48 GlobalRate=12708.43 Time=Tue Jun  3 09:26:28 2025
# [xla:0](340) Loss=0.08690 Rate=16834.64 GlobalRate=12940.06 Time=Tue Jun  3 09:26:29 2025
# [xla:0](360) Loss=0.01944 Rate=15073.18 GlobalRate=12989.70 Time=Tue Jun  3 09:26:29 2025
# [xla:0](380) Loss=0.02995 Rate=13611.75 GlobalRate=12970.72 Time=Tue Jun  3 09:26:29 2025
# [xla:0](400) Loss=0.01613 Rate=14050.78 GlobalRate=13032.89 Time=Tue Jun  3 09:26:29 2025
# [xla:0](420) Loss=0.02084 Rate=16570.16 GlobalRate=13212.36 Time=Tue Jun  3 09:26:29 2025
# [xla:0](440) Loss=0.00982 Rate=15447.95 GlobalRate=13273.27 Time=Tue Jun  3 09:26:29 2025
# [xla:0](460) Loss=0.02529 Rate=11228.74 GlobalRate=12949.03 Time=Tue Jun  3 09:26:30 2025
# Finished training epoch 10
# [xla:0] Accuracy=98.93%
