# %% [markdown]
# # Exercise 2: K-Means Clsutering

# %%
import sklearn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#generate random cluster data with lables
from sklearn.datasets.samples_generator import make_blobs
X, y = make_blobs(n_samples=500, centers=3, n_features=2,random_state=0)

# %%
#plot
plt.scatter(X[:, 0], X[:, 1], marker='.', c=y, cmap='viridis', alpha=0.25);

# %% [markdown]
# ## Implement *K-Means* (see slides) with ***NumPy***
# Hint: this is quite similar to the Histogram

# %% [markdown]
# ## Implement *K-Means* with ***DASK*** Arrays
